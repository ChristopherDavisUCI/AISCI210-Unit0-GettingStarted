# %% [markdown]
# # Class 1 - Getting Started with GitHub, Jupyter Notebooks, and Python

# %% [markdown]
# ## Variables

# %%
2+3
# Out:
# 5

# %% [markdown]
# To create a new cell on Mac after executing, hold down option while you hit return.  On Windows, `alt+return`.

# %%
x = 2+3

# %%
print(x)
# Out:
# 5

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# %%
df = pd.read_csv("data/penguins.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 18.9 KB

# %% [markdown]
# ## Example: Plotting from the penguins dataset

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'
